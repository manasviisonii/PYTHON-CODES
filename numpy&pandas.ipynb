# %% [markdown]
# using pandas and numpy

# %%
import pandas as pal
import numpy as np

pf=pal.DataFrame(data =np.arange(0,20).reshape(4,5),index=["Row1","Row2","Row3","Row4"],columns=["Col1","Col2","Col3","Col4","Col5",])
pf.describe()
pf.info()
pf.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Row1 to Row4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    4 non-null      int64
#  1   Col2    4 non-null      int64
#  2   Col3    4 non-null      int64
#  3   Col4    4 non-null      int64
#  4   Col5    4 non-null      int64
# dtypes: int64(5)
# memory usage: 192.0+ bytes
#       Col1  Col2  Col3  Col4  Col5
# Row1     0     1     2     3     4
# Row2     5     6     7     8     9
# Row3    10    11    12    13    14
# Row4    15    16    17    18    19
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Col1'].plot(kind='hist', bins=20, title='Col1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Col2'].plot(kind='hist', bins=20, title='Col2')
# ...
